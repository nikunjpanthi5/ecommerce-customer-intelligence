# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load processed data
df = pd.read_csv('D:/ecommerce-customer-intelligence/data/processed/ecommerce_clean.csv')

# Quick sanity check
print("Shape:", df.shape)
print("Missing values:", df.isnull().sum().sum())
print("Date range:", df['InvoiceDate'].min(), "to", df['InvoiceDate'].max())
# Out:
# Shape: (397884, 10)
# Missing values: 0
# Date range: 1/10/2011 10:32 to 9/9/2011 9:52

# %%
# CSV doesn't remember datetime — fix it every time you load
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
print(df['InvoiceDate'].dtype)  # Should show datetime64
# Out:
# datetime64[ns]
